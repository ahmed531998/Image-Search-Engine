# %%
#Getting the Bird Images
! gdown --id 1ipEh7OK5c1YXHFI-AleRJdeUfFcXedGX
! mkdir -p data && unzip -q -d data 100-bird-species.zip
! rm 100-bird-species.zip

#Getting the Distractor Images
! gdown --id 1W2OKpakiBx5WkBhCS-s9KZtdfs_6r3Oi
! unzip -q DistractormY2pWptmp
! rm DistractormY2pWptmp
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ipEh7OK5c1YXHFI-AleRJdeUfFcXedGX
# To: /content/100-bird-species.zip
# 100% 1.25G/1.25G [00:11<00:00, 105MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1W2OKpakiBx5WkBhCS-s9KZtdfs_6r3Oi
# To: /content/DistractormY2pWptmp
# 100% 3.08G/3.08G [01:09<00:00, 44.1MB/s]

# %%
# Downloading REST_Support.ipynb, LSH.ipynb and app.py
! gdown --id 1SaKx0JFYHuGUDZo_bO63FtFaYQtAa9Np 
! gdown --id 1BfkIKfpGkUCKWNod3JkOMYqhInIHG2M1
! gdown --id 1oujyzRwk4Eoa9oNPiE2dfZ-N2h9VrSHf
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1SaKx0JFYHuGUDZo_bO63FtFaYQtAa9Np
# To: /content/REST_Support.ipynb
# 100% 26.9k/26.9k [00:00<00:00, 7.96MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1BfkIKfpGkUCKWNod3JkOMYqhInIHG2M1
# To: /content/LSH.ipynb
# 100% 214k/214k [00:00<00:00, 6.77MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1oujyzRwk4Eoa9oNPiE2dfZ-N2h9VrSHf
# To: /content/app.py
# 100% 1.02k/1.02k [00:00<00:00, 1.70MB/s]

# %%
# Installing flask to run the API server 
# !pip install flask
! pip install flask_cloudflared
import flask

# Installing import-ipynb to import other colab notebooks
# !pip install import-ipynb
# Out:
# ...
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=1c79d2fe4e3f730a36e029159f3e8dbeadfa71027d458233d012fa8a308bbe1a
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# ...

# %%
# Running the flask server
# !python3 app.py
# Out:
# importing Jupyter notebook from REST_Support.ipynb
# importing Jupyter notebook from LSH.ipynb
# Downloading...
# From: https://drive.google.com/uc?id=1PkbSO8Jn5QEV2ufrD5fwL848xirBs0mW
# To: /content/training_set.csv
# 100%|██████████████████████████████████████| 2.24M/2.24M [00:00<00:00, 35.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FpSx5nDARAUqe8NPgisDXHzE8B50TD0p
# To: /content/distractor.csv
# 100%|████████████████████████████████████████| 864k/864k [00:00<00:00, 13.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1bHWVBTYMhKyDqDinkv4QORy0eq_ih237
# To: /content/train_descriptors.npy
# 100%|██████████████████████████████████████| 82.9M/82.9M [00:01<00:00, 68.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YbNMPkxgKVvFEIq0_fTr83X1LGgNOIh_
# To: /content/distractor.npy
# 100%|██████████████████████████████████████| 51.2M/51.2M [00:00<00:00, 59.0MB/s]
# rm: cannot remove 'test_descriptors.npy': No such file or directory
# ...
